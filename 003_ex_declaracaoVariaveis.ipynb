# %%
nome = "Francis" # Variável do tipo string
idade = 30 # Variável do tipo inteiro
altura = 1.75 # Variável do tipo float
estudante = True # Variável do tipo booleano

# %%
print(f"Nome: {nome}")
print(f"Idade: {idade}")
print(f"Altura: {altura}")
print(f"Estudante: {estudante}")

# %%
frase = "Aprender Python é divertido!"

# %%
#concatenação de string
nome ="Francis"
saudacao = "Ola, " + nome + "!"
print(saudacao)

# %%
#tamanho da frase
print(f"Tamanho da frase: {len(frase)} caracteres")
